# %%
# -*- coding: utf-8 -*-
"""
Created on Sat May 13 00:22:21 2023

@author: atlan
"""
# -*- coding: utf-8 -*-
"""
Created on Tue Dec 14 21:58:48 2021

@author: atlan
"""
import random
import math
import copy

monomer_list = []
shuffled_monomer_list = []
free_monomer_list = []
molecule_list = []   
    
initiator_list = []
crosslinker_list = []
TTC_list = []
TFK_list = []
chain_list = []
    
j = 0



current_parameters = {
    'repeats' : 10,
    'conversion' : 0.8,

    'Repeat_unit_length' : 2,
    'crosslinker_length' : 16,
    'TTC_length' : 2,
    'TFK_TTC_length' : 2,
    'TFK_arm_length' : 7,

    'monomer_number' : 10000,
    'crosslinker_number' : 4000,
    'TTC_number' : 0,
    'TFK_number' : 0,
    'initiator_number' : 10,

    'k_transfer_to_ttc' : 220,
    'k_transfer_to_TFK' : 220,
    
    'r1' : 1,
    'r2' : 1
     }

batch_exprmnts = [
    {
    'monomer_number' : 15000,
    'crosslinker_number' : 5000,
    'TTC_number' : 0,
    'TFK_number' : 0,
    'initiator_number' : 62,
     },
    
    
    {
    'monomer_number' : 15000,
    'crosslinker_number' : 4750,
    'TTC_number' : 0,
    'TFK_number' : 250,
    'initiator_number' : 62,
     },
                  
     {
    'monomer_number' : 15000,
    'crosslinker_number' : 4250,
    'TTC_number' : 0,
    'TFK_number' : 750,
    'initiator_number' : 62,
     },
     
     {
    'monomer_number' : 15000,
    'crosslinker_number' : 3750,
    'TTC_number' : 0,
    'TFK_number' : 1250,
    'initiator_number' : 62,
    'r1' : 1,
    'r2' : 1
     },
     
    
    {
    'monomer_number' : 15000,
    'crosslinker_number' : 5000,
    'TTC_number' : 250,
    'TFK_number' : 0,
    'initiator_number' : 62,
     },
                  
     {
    'monomer_number' : 15000,
    'crosslinker_number' : 5000,
    'TTC_number' : 750,
    'TFK_number' : 0,
    'initiator_number' : 62,
     },
     
     {
    'monomer_number' : 15000,
    'crosslinker_number' : 5000,
    'TTC_number' : 1250,
    'TFK_number' : 0,
    'initiator_number' : 62,
    'r1' : 1,
    'r2' : 1
     },
    
    

#     {
#     'monomer_number' : 1500,
#     'crosslinker_number' : 500,
#     'TTC_number' : 0,
#     'TFK_number' : 0,
#     'initiator_number' : 6,
#      },
      
#      {
#     'monomer_number' : 1500,
#     'crosslinker_number' : 475,
#     'TTC_number' : 0,
#     'TFK_number' : 25,
#     'initiator_number' : 6,
#      },
                  
#      {
#     'monomer_number' : 1500,
#     'crosslinker_number' : 425,
#     'TTC_number' : 0,
#     'TFK_number' : 75,
#     'initiator_number' : 6,
#      },
                               
#      {
#     'monomer_number' : 1500,
#     'crosslinker_number' : 375,
#     'TTC_number' : 0,
#     'TFK_number' : 125,
#     'initiator_number' : 6,
#      },
    
      
#      {
#     'monomer_number' : 1500,
#     'crosslinker_number' : 500,
#     'TTC_number' : 25,
#     'TFK_number' : 0,
#     'initiator_number' : 6,
#      },
                  
#      {
#     'monomer_number' : 1500,
#     'crosslinker_number' : 500,
#     'TTC_number' : 75,
#     'TFK_number' : 0,
#     'initiator_number' : 6,
#      },
                               
#      {
#     'monomer_number' : 1500,
#     'crosslinker_number' : 500,
#     'TTC_number' : 125,
#     'TFK_number' : 0,
#     'initiator_number' : 6,
#      }


     ]
    
    
     
def batch_init(exprmnt, current_dict):
    global repeats
    global conversion
    global Repeat_unit_length
    global crosslinker_length
    global TTC_length         
    global TFK_TTC_length     
    global TFK_arm_length     
        
    global monomer_number
    global crosslinker_number    
    global TTC_number         
    global TFK_number         
    global initiator_number   
        
    global k_transfer_to_ttc  
    global k_transfer_to_TFK  

    global r1
    global r2
    
    for key in current_parameters:
        if key in exprmnt:
            current_parameters[key] = exprmnt[key]
            
    repeats            = current_dict['repeats']
                    
    conversion         = current_dict['conversion']
        
    Repeat_unit_length = current_dict['Repeat_unit_length']
    crosslinker_length = current_dict['crosslinker_length']
    TTC_length         = current_dict['TTC_length']
    TFK_TTC_length     = current_dict['TFK_TTC_length']
    TFK_arm_length     = current_dict['TFK_arm_length']
        
    monomer_number     = current_dict['monomer_number']
    crosslinker_number = current_dict['crosslinker_number']
    TTC_number         = current_dict['TTC_number']
    TFK_number         = current_dict['TFK_number']
    initiator_number   = current_dict['initiator_number']
            
    k_transfer_to_ttc  = current_dict['k_transfer_to_ttc']
    k_transfer_to_TFK  = current_dict['k_transfer_to_TFK']
    
    r1                  = current_dict['r1']
    r2                  = current_dict['r2']
    
    monomer = monomer_number - crosslinker_number * 2 - TFK_number * 2
    
    print('monomer = ', monomer)
    print('crosslinker = ', crosslinker_number)
    print('TTC = ', TTC_number)
    print('TFK = ', TFK_number)
    print('initiator = ', initiator_number)
    print('r1 = ', r1)
    print('r2 = ', r2)
            
            

class chain:
    
    def __init__ (self, head, tail, head_type = None, elastic = True):
        self.kind = 'chain' #both 'type' and 'id' are reserved...
        self.component = []
        self.neighbors = []
        self.head = head
        self.tail = tail
        self.head_type = head_type
        self.head_length = 0
        self.elastic = elastic
            
    def activate(self):
        self.tail = 'radical'
        
    def dormant(self, new_tail):
        self.tail = new_tail
        
class TTC:
    def __init__ (self, chain1, chain2, flank1 = 0, flank2 = 0, elastic = 0):
        self.kind = 'ttc'
        self.chain1 = chain1
        self.chain2 = chain2
        self.flank1 = flank1
        self.flank2 = flank2
        self.elastic = elastic

class TFK:
    def __init__ (self, chain1, chain2, monomer1, monomer2, flank1 = 0, flank2 = 0, elastic = 0):
        self.kind = 'TFK'
        self.chain1 = chain1
        self.chain2 = chain2
        self.monomer1 = monomer1
        self.monomer2 = monomer2
        self.flank1 = flank1
        self.flank2 = flank2
        self.elastic = elastic
        
class crosslinker:
    def __init__ (self, monomer1,monomer2, elastic = None):
        self.kind = 'crosslinker'
        self.monomer1 = monomer1
        self.monomer2 = monomer2
        self.elastic = elastic
        self.length = crosslinker_length
        
class monomer:
    def __init__(self, kind, free = True, parent = None, chain = None): #"type" can be used to denote different kinds of polymerizable groups, e.g. acrylate/styrene copolymerization
        self.kind = kind
        self.free = free
        self.parent = parent
        self.chain = chain


def initiation():
    
    monomer_list.clear()
    shuffled_monomer_list.clear()
    free_monomer_list.clear()
    
    
    initiator_list.clear()
    crosslinker_list.clear()
    TTC_list.clear()
    TFK_list.clear()
    chain_list.clear()
    
    
    j = 0

    for i in range(initiator_number):
        initiator_list.append(i)
        
    for i in range(TTC_number):
        TTC_list.append(TTC(None,None))
    
    
    for i in range(monomer_number):
        monomer_list.append(monomer(kind = 1, free = True))
    
    
    j = 0
    
    
    for i in range(crosslinker_number):
        crosslinker_list.append(crosslinker(monomer_list[j],monomer_list[j+1]))
        monomer_list[j].parent = crosslinker_list[i]
        monomer_list[j+1].parent = crosslinker_list[i]
        j += 2
    
    for i in range(TFK_number):
        TFK_list.append(TFK(None, None, monomer_list[j], monomer_list[j+1]))
        monomer_list[j].parent = TFK_list[i]
        monomer_list[j+1].parent = TFK_list[i]
        j += 2
    
    
    j = 0
    
    for trithiocarbonate in TTC_list:
         chain_list.append(chain(head=None, tail=trithiocarbonate))
         chain_list.append(chain(head=None, tail=trithiocarbonate))
         trithiocarbonate.chain1 = chain_list[j]
         trithiocarbonate.chain2 = chain_list[j+1]
         j += 2
         
    for iniferinker in TFK_list:
         chain_list.append(chain(head=iniferinker.monomer1, tail=iniferinker, head_type = 'monomer'))
         chain_list.append(chain(head=iniferinker.monomer2, tail=iniferinker, head_type = 'monomer'))
         iniferinker.monomer1.parent = chain_list[j]
         iniferinker.monomer2.parent = chain_list[j+1]
         iniferinker.chain1 = chain_list[j]
         iniferinker.chain2 = chain_list[j+1]
         iniferinker.monomer1.kind = 2
         iniferinker.monomer2.kind = 2
         j += 2


    for initiator in initiator_list:
         chain_list.append(chain(head=None,tail='radical'))
         #print(chain_list[-1].head)
 
# =============================================================================
#     for xlinker in crosslinker_list:
#         xlinker.monomer1.kind = 2
#         xlinker.monomer2.kind = 2
# =============================================================================

def chain_transfer(chain, CTA_list):
 
     TTC = random.choice(CTA_list)
     chain.dormant(new_tail = TTC)
     TTC_side = random.choice([1,2])
     if TTC_side == 1:
         TTC.chain1.activate()
         TTC.chain1 = chain
     else:
         TTC.chain2.activate()
         TTC.chain2 = chain


def terminate(chain):
    chain.dormant(new_tail = 'terminate')


def chain_grow_alt(chain, counter):
    
    weights = [k_transfer_to_ttc * TTC_number, k_transfer_to_TFK * TFK_number, monomer_number - j]
    switch = random.choices(['transfer_ttc','transfer_TFK','propagate'], weights = weights)
    
    if switch == ['transfer_ttc']:
        chain_transfer(chain, TTC_list)
        return 0
        
    elif switch == ['transfer_TFK']:
        chain_transfer(chain, TFK_list)
        return 0
    
    elif switch == ['terminate']:
        terminate(chain)
        return -1
    
    else:
        new_monomer = random.choice(monomer_list)
        while new_monomer.free == False:
            new_monomer = random.choice(monomer_list)
        chain.component.append(new_monomer)
        new_monomer.free = False
        new_monomer.chain = chain
        return 1
    
    
def chain_grow(chain):
    
    weights = []
    
    for molecule in molecule_list:
        if molecule.kind == 'ttc':
            weights.append(k_transfer_to_ttc)
        elif molecule.kind == 'TFK':
            weights.append(k_transfer_to_TFK)
        elif molecule.kind == 1:
            if len(chain.component) == 0:
                weights.append(1)
            elif chain.component[-1].kind == 1:
                weights.append(1)
            elif chain.component[-1].kind == 2:
                weights.append(1/r1)
        elif molecule.kind == 2:
            if len(chain.component) == 0:
                weights.append(1)
            elif chain.component[-1].kind == 1:
                weights.append(1/r2)
            elif chain.component[-1].kind == 2:
                weights.append(1)
        else:
            print('Molecule reactivity not defined')
    
    reacted = random.choices(molecule_list, weights = weights)
    reacted = reacted[0]

    if reacted.kind == 'ttc' or reacted.kind == 'TFK':
        chain.dormant(new_tail = reacted)
        TTC_side = random.choice([1,2])
        if TTC_side == 1:
            reacted.chain1.activate()
            reacted.chain1 = chain
        else:
            reacted.chain2.activate()
            reacted.chain2 = chain
        return 0
    
    elif reacted.kind == 1 or reacted.kind ==2:
        chain.component.append(reacted)
        reacted.free = False
        reacted.chain = chain
        molecule_list.remove(reacted)
        return 1
    else:
        print('Molecule reactivity not defined')
        
        
def simulation():
    
    molecule_list.clear()
    
    for monomer in monomer_list:
        molecule_list.append(monomer)
        
    for TFK in TFK_list:
        molecule_list.append(TFK)
    
    for TTC in TTC_list:
        molecule_list.append(TTC)
        
    j = 0
    live_chains = initiator_number
    
    while (j < monomer_number * conversion) and live_chains > 0: 
        #print(j)

        chain = random.choice(chain_list)
           
        if chain.tail == 'radical':
            grow_outcome = chain_grow(chain)
               
            if grow_outcome == 1:
                    j += 1
                   
            elif grow_outcome == -1:
                    live_chains -= 1
                
    

def MW_Calculator():
    w = 0
    wsq = 0
    n = 0
    for chain in chain_list:
    #    print (len(chain.component))
     #   print (chain.tail)
        if len(chain.component) == 0:
            continue
            
        dict_write(chain_length, {len(chain.component) : 1})
        chain_length_list.append(len(chain.component))
        
        w += len(chain.component)
        wsq += len(chain.component)*len(chain.component)
        n += 1
    
    mw = wsq/w
    mn = w/n
    print (mw, mn, mw/mn)
    print(len(chain_list))
    return mn, mw/mn

def dict_write(master_dict, new_dict):
    for key in new_dict:
        if key in master_dict:
            master_dict[key] += new_dict[key]
        else:
            master_dict[key] = new_dict[key]
            
            
def chain_neighbors(chain_list):
    
    for chain0 in chain_list:
        loops = 0
        neighbors_list = []
        if chain0.head_type == 'monomer' and chain0.head.free == False:
            neighbors_list.append(chain0.head.chain)
            if chain0.head.chain == chain0:
                loops += 1
        for monomer in chain0.component:
            if type(monomer.parent) == chain:
                neighbors_list.append(monomer.parent)
            if type(monomer.parent) == crosslinker:
                if monomer.parent.monomer1.free == True or monomer.parent.monomer2.free == True:
                    continue
                else:
                    if monomer.parent.monomer1.chain == monomer.parent.monomer2.chain and monomer.parent.monomer1.chain == chain0:
                        loops += 1
                    neighbors_list.append(monomer.parent.monomer2.chain)
                    neighbors_list.append(monomer.parent.monomer1.chain)
                        
        if type(chain0.tail) == TFK or type(chain0.tail) == TTC:
            if chain0.tail.chain1 == chain0:
                neighbors_list.append(chain0.tail.chain2)
            else:
                neighbors_list.append(chain0.tail.chain1)
        
        neighbors_list = list(set(neighbors_list))
        
        if chain0 in neighbors_list:
            neighbors_list.remove(chain0)
            
        #print(len(neighbors_list))
        
        chain0.neighbors = neighbors_list
        #print("loops", loops)
        
    for chain0 in chain_list:
        #print(len(chain0.neighbors))
        if len(chain0.neighbors) < 2:
            chain0.elastic =False
    
    removed_chains = 1
    while removed_chains > 0:
        removed_chains = 0
        for chain0 in chain_list:
            if chain0.elastic == False:
                continue
            
            elastic_connections = len(chain0.neighbors)
            
            for neighbor in chain0.neighbors:
                if neighbor.elastic == False:
                    elastic_connections -= 1
            if elastic_connections < 2:
                chain0.elastic = False
                removed_chains += 1
        #print('removed_chains', removed_chains)

def crosslinker_elastic(crosslinker_list, chain_list):
    
    elastic_crosslinkers = 0
    
    for crosslinker0 in crosslinker_list:
        if crosslinker0.monomer1.free == True or crosslinker0.monomer2.free == True:
            crosslinker0.elastic = False
            continue
        elif crosslinker0.monomer1.chain.elastic == False or crosslinker0.monomer2.chain.elastic == False:
            crosslinker0.elastic = False
    
    for chain0 in chain_list:
        primary_loops = 0
        last_crosslink = chain0
        
        for monomer in chain0.component:
            if monomer.parent == None:
                continue
            #print(last_crosslink)
            #print(monomer.parent)
            
            if monomer.parent == last_crosslink:
                primary_loops += 1
                if type(monomer.parent) == crosslinker:
                    monomer.parent.elastic = False
            
        #print(primary_loops)
    
    elastic_crosslinker_list = []
    for crosslinker0 in crosslinker_list:
        if crosslinker0.elastic != False:
            elastic_crosslinkers+=1
            elastic_crosslinker_list.append(crosslinker0)
    
    #return ({crosslinker_length:elastic_crosslinkers})
    return(elastic_crosslinker_list)
        

def xlinker_at_terminal(elastic_crosslinker_list, chain_list): 
    
#considers the first and last crosslinking point on a chain which are not true crosslinking points as only two chains join
    
    chain_end_dict = {}
    
    for chain0 in chain_list:        
        if chain0.head_type == 'monomer' and chain0.head.free == False:
            chain0.head_length = TFK_arm_length
        else:
            #print('length',len(chain0.component))
            buffer = 0
            elastic_active = 0
            for monomer in chain0.component:
                
                if elastic_active > 2: break
                if elastic_active == 1:
                    buffer += Repeat_unit_length
                    
                if hasattr(monomer.parent, 'elastic') and monomer.parent.elastic != False:
                    elastic_active += 1
                    if elastic_active == 2:
                        chain_end_dict[monomer] = buffer
                        break
            
        if type(chain0.tail) == TFK or type(chain0.tail) == TTC:
            continue
        if len(chain0.neighbors) <= 2:
            continue
        else:
            buffer = 0
            elastic_active = 0
            for monomer in reversed(chain0.component):
                
                if elastic_active > 2: break
                if elastic_active == 1:
                    buffer += Repeat_unit_length
                    
                if hasattr(monomer.parent, 'elastic') and monomer.parent.elastic != False:
                    elastic_active += 1
                    if elastic_active == 2:
                        chain_end_dict[monomer] = buffer
                        break
    
    
    
    #print(len(chain_end_dict))
    for chain0 in chain_list:
         if chain0.head_type == 'monomer' and chain0.head.free == False:
             
             if chain0.head in chain_end_dict:
                chain0.head_length += chain_end_dict[chain0.head]
                
    elastic_crosslinkers_dict = {}
    
    for crosslinker0 in elastic_crosslinker_list:
        
        if crosslinker0.monomer1 in chain_end_dict:
            crosslinker0.length += chain_end_dict[crosslinker0.monomer1]
        
        if crosslinker0.monomer2 in chain_end_dict:
            crosslinker0.length += chain_end_dict[crosslinker0.monomer2]
            
        dict_write(elastic_crosslinkers_dict, {crosslinker0.length :1})
        
    drop_list = list(chain_end_dict.values())
    #print(drop_list)
    
    return elastic_crosslinkers_dict,  drop_list

        

def MW_btw_Xlink_Calc(crosslinker, TFK, TTC, monomer):
    MW_btw_Xlink = {}
     
    chain_neighbors(chain_list)
    elastic_crosslinker_list = crosslinker_elastic(crosslinker_list, chain_list)
    elastic_crosslinkers_dict, drop_list = xlinker_at_terminal(elastic_crosslinker_list, chain_list)
    
    dict_write(MW_btw_Xlink, elastic_crosslinkers_dict)
    
    for chain0 in chain_list:

        if chain0.elastic == False:
            continue
        #print('length', len(chain0.component), 'neighbors',len(chain0.neighbors))
        elastic_active = False
        buffer = 0
        
        if chain0.head_type == 'monomer' and chain0.head.free == False:
            elastic_active = True
            buffer += chain0.head_length
        a=0
        b=0
        c=0
        d=0

        
        for monomer in chain0.component:
        
            buffer += Repeat_unit_length
            #print(monomer.parent)
            if monomer.parent == None:
                a+=1
                continue
            
            elif hasattr(monomer.parent, 'elastic') and monomer.parent.elastic == False:
                
                #print(monomer.parent)
                #if monomer.parent.elastic == False:
                b+=1
                continue
            
            elif elastic_active == True:
                c+=1
                dict_write(MW_btw_Xlink,{buffer:1})
                buffer = 0

            else:
                d+=1
                elastic_active = True
                buffer = 0
        
        #print('a=',a,'b=',b,'c=',c,'d=',d, )
        
        if type(chain0.tail) == TFK or type(chain0.tail) == TTC:
            chain0.tail.flank1 += buffer
            if chain0.elastic == False:
                chain0.tail.elastic = -1
    
    for value in drop_list:
        dict_write(MW_btw_Xlink,{value: -1})

    for TFK in TFK_list:
        if TFK.elastic == -1 :
            continue   
        buffer = TFK_TTC_length + TFK.flank1
        dict_write(MW_btw_Xlink,{buffer:1})   
        
    for TTC in TTC_list:
        if TTC.elastic == -1 :
            continue
    
        buffer = TTC_length + TTC.flank1
        dict_write(MW_btw_Xlink,{buffer:1})
            
    return MW_btw_Xlink


def Avg_XL_per_Chain():
    xlink_number_by_mw = 0
    chain_number = 0
    monomer_number = 0
    #print('chain number', len(chain_list))
    for chain in chain_list:   
        
        chain_xlink_number = 0
        chain_monomer_number = 0
        
        if len(chain.component) == 0:
            continue    
        
        if chain.head != None:
            
            if chain.head.free == False:
                chain_xlink_number += 1
        
        if type(chain.tail) == TFK:
            
            if chain.tail.chain1 == chain:
                other_chain = chain.tail.chain2
            else: 
                other_chain = chain.tail.chain1
            
            if other_chain.head != None:
                if other_chain.head.free == False:
                    chain_xlink_number += 1
            
            elif len(other_chain.component) > 0:
                chain_xlink_number += 1
        
        for monomer in chain.component:
         
            chain_monomer_number += 1

            if monomer.parent != None:
                chain_xlink_number += 1
                
        chain_number += 1
        
        xlink_number_by_mw += chain_xlink_number
        monomer_number += len(chain.component)
    
    return {"xlink_number_by_mw":xlink_number_by_mw, "monomer_number":monomer_number, "chain_number":chain_number}
                
    
    
all_data = []
all_chain_lengths = []

all_chain_list = []
all_mw_data = []

for exprmnt in batch_exprmnts:
    pdi = 0
    data = {}
    chain_length = {}
    chain_length_list= []
    chain_list_list = []
    mw_data = []
    
    Avg_XL = {"xlink_number_by_mw":0, "monomer_number":0,"chain_number":0}
    batch_init(exprmnt, current_parameters)
    for repeat in range(repeats):
        initiation()

        simulation()
        
        pdi = MW_Calculator()
        MW_btw_Xlink = MW_btw_Xlink_Calc(crosslinker, TFK, TTC, monomer)
        dict_write(data,MW_btw_Xlink)
        
        total = 0
        segments = 0
        sqr = 0
        for i in MW_btw_Xlink:
            sqr += data[i] * i * i 
            total += data[i] * i
            segments += data[i]
            
        print('1Mn_btw_Xlinks = ' , total/segments)
        print('1Mw_btw_Xlinks = ' , sqr/total)
        print("1Total MW = ", total) 
    
        chain_list_list.append(chain_list.copy())
        mw_data.append({'mn':total/segments, 'mw':sqr/total, 'total_mw':total})
        
        dict_write(Avg_XL, Avg_XL_per_Chain())
        #print(Avg_XL, Avg_XL['xlink_number_by_mw']/Avg_XL['chain_number'])

    total = 0
    segments = 0
    sqr = 0
    for i in data:
        sqr += data[i] * i * i 
        total += data[i] * i
        segments += data[i]
        
    print('Mn_btw_Xlinks = ' , total/segments)
    print('Mw_btw_Xlinks = ' , sqr/total)
    print("Total Segments = ", segments) 
    print("Total MW = ", total) 
    print('pdi=', pdi)
    
    all_chain_lengths.append(chain_length_list)
    all_chain_list.append(chain_list_list)
    all_mw_data.append(mw_data)
    
    import matplotlib.pylab as plt
    
    lists = sorted(data.items()) # sorted by key, return a list of tuples
    x, y = zip(*lists) # unpack a list of pairs into two tuples
    plt.figure(dpi=300)
    all_data.append([x,y])
    plt.bar(x, y)
    plt.show()
    
    import csv 
  
    filename = str(monomer_number) + ',crosslinker = ' + str(crosslinker_number) + ',TTC = ' + str(TTC_number) + ',TFK = ' + str(TFK_number) + ',initiator = ' + str(initiator_number) + ',r1 = ' + str(r1) + ',r2 = ' + str(r2) + '.csv'

    file = open(filename, 'w+', newline ='') 
  
    with file: 
        write = csv.writer(file) 
        write.writerows([['monomer = ', monomer_number - 2 * (crosslinker_number + TFK_number)],['crosslinker = ', crosslinker_number],['TTC = ', TTC_number],['TFK = ', TFK_number],['initiator = ', initiator_number],['r1 = ', r1],['r2 = ', r2]])
        write.writerows(lists)
# Out:
# monomer =  5000
# crosslinker =  5000
# TTC =  0
# TFK =  0
# initiator =  62
# r1 =  1
# r2 =  1
# 194.65816666666666 193.5483870967742 1.005733861111111
# 62
# 1Mn_btw_Xlinks =  7.934177215189873
# 1Mw_btw_Xlinks =  12.86322059136354
# 1Total MW =  75216
# 194.5325 193.5483870967742 1.0050845833333333
# 62
# 1Mn_btw_Xlinks =  7.945759838974522
# 1Mw_btw_Xlinks =  12.880379713081968
# 1Total MW =  150008
# 194.51583333333335 193.5483870967742 1.0049984722222223
# 62
# 1Mn_btw_Xlinks =  7.95057613898245
# 1Mw_btw_Xlinks =  12.867957510947798
# 1Total MW =  224246
# 194.47883333333334 193.5483870967742 1.0048073055555555
# 62
# 1Mn_btw_Xlinks =  7.951483912107767
# 1Mw_btw_Xlinks =  12.867457479867678
# 1Total MW =  299270
# 194.162 193.5483870967742 1.0031703333333333
# 62
# 1Mn_btw_Xlinks =  7.950977060322855
# 1Mw_btw_Xlinks =  12.868255986664245
# 1Total MW =  374332
# 194.778 193.5483870967742 1.0063529999999998
# 62
# 1Mn_btw_Xlinks =  7.954153000620512
# 1Mw_btw_Xlinks =  12.867617362154355
# 1Total MW =  448654
# 194.5545 193.5483870967742 1.0051982499999998
# 62
# 1Mn_btw_Xlinks =  7.953085594482088
# 1Mw_btw_Xlinks =  12.863347392872425
# 1Total MW =  523488
# 194.52016666666665 193.5483870967742 1.0050208611111109
# 62
# 1Mn_btw_Xlinks =  7.953118982163964
# 1Mw_btw_Xlinks =  12.875103114991166
# 1Total MW =  598846
# 194.14116666666666 193.5483870967742 1.0030626944444443
# 62
# 1Mn_btw_Xlinks =  7.941461802646021
# 1Mw_btw_Xlinks =  12.85041195563006
# 1Total MW =  672888
# 194.49516666666668 193.5483870967742 1.0048916944444444
# 62
# 1Mn_btw_Xlinks =  7.946339390075444
# 1Mw_btw_Xlinks =  12.857184119385423
# 1Total MW =  747830
# Mn_btw_Xlinks =  7.952452277000542
# Mw_btw_Xlinks =  12.874740188613716
# Total Segments =  94137
# Total MW =  748620
# pdi= (193.5483870967742, 1.0048916944444444)
# monomer =  5000
# crosslinker =  4750
# TTC =  0
# TFK =  250
# initiator =  62
# r1 =  1
# r2 =  1
# 22.533 21.352313167259787 1.0552955
# 562
# 1Mn_btw_Xlinks =  8.021618743343984
# 1Mw_btw_Xlinks =  12.892410020843567
# 1Total MW =  75323
# 22.6045 21.352313167259787 1.0586440833333335
# 562
# 1Mn_btw_Xlinks =  8.004977495366694
# 1Mw_btw_Xlinks =  12.880164578565097
# 1Total MW =  151174
# 22.621833333333335 21.352313167259787 1.0594558611111111
# 562
# 1Mn_btw_Xlinks =  8.00265064499028
# 1Mw_btw_Xlinks =  12.86366948572438
# 1Total MW =  226435
# 22.600833333333334 21.352313167259787 1.058472361111111
# 562
# 1Mn_btw_Xlinks =  8.005442718704368
# 1Mw_btw_Xlinks =  12.868800265317967
# 1Total MW =  301525
# 22.717833333333335 21.352313167259787 1.0639518611111112
# 562
# 1Mn_btw_Xlinks =  8.00421967769296
# 1Mw_btw_Xlinks =  12.873163805138828
# 1Total MW =  377479
# 22.675833333333333 21.352313167259787 1.0619848611111111
# 562
# 1Mn_btw_Xlinks =  7.995618297143059
# 1Mw_btw_Xlinks =  12.86153390609532
# 1Total MW =  452544
# 22.616333333333333 21.352313167259787 1.0591982777777778
# 562
# 1Mn_btw_Xlinks =  8.009354863164278
# 1Mw_btw_Xlinks =  12.88554434678575
# 1Total MW =  528257
# 22.611666666666668 21.352313167259787 1.0589797222222224
# 562
# 1Mn_btw_Xlinks =  8.000981250165752
# 1Mw_btw_Xlinks =  12.864355487200564
# 1Total MW =  603386
# 22.504666666666665 21.352313167259787 1.0539685555555554
# 562
# 1Mn_btw_Xlinks =  8.003491924923614
# 1Mw_btw_Xlinks =  12.87136219989623
# 1Total MW =  678432
# 22.603 21.352313167259787 1.0585738333333334
# 562
# 1Mn_btw_Xlinks =  8.008229535004725
# 1Mw_btw_Xlinks =  12.88498711810109
# 1Total MW =  754159
# Mn_btw_Xlinks =  8.01089333871276
# Mw_btw_Xlinks =  12.891991401087322
# Total Segments =  94186
# Total MW =  754514
# pdi= (21.352313167259787, 1.0585738333333334)
# monomer =  5000
# crosslinker =  4250
# TTC =  0
# TFK =  750
# initiator =  62
# r1 =  1
# r2 =  1
# 8.786333333333333 7.682458386683739 1.1436877222222221
# 1562
# 1Mn_btw_Xlinks =  8.087456482751344
# 1Mw_btw_Xlinks =  12.76360861454977
# 1Total MW =  76661
# 8.824833333333334 7.682458386683739 1.148699138888889
# 1562
# 1Mn_btw_Xlinks =  8.123890967397115
# 1Mw_btw_Xlinks =  12.790891985420862
# 1Total MW =  151998
# 8.752833333333333 7.687379884689301 1.1385977361111113
# 1562
# 1Mn_btw_Xlinks =  8.127368083056833
# 1Mw_btw_Xlinks =  12.80628791669959
# 1Total MW =  227802
# 8.898666666666667 7.682458386683739 1.1583097777777778
# 1562
# 1Mn_btw_Xlinks =  8.119503584037659
# 1Mw_btw_Xlinks =  12.795119444481045
# 1Total MW =  303572
# 8.7195 7.687379884689301 1.1342616250000002
# 1562
# 1Mn_btw_Xlinks =  8.109831274930142
# 1Mw_btw_Xlinks =  12.783480669232004
# 1Total MW =  380197
# 8.807333333333334 7.6972418216805645 1.144219388888889
# 1562
# 1Mn_btw_Xlinks =  8.115962407888647
# 1Mw_btw_Xlinks =  12.787767204493269
# 1Total MW =  455971
# 8.779166666666667 7.687379884689301 1.142023263888889
# 1562
# 1Mn_btw_Xlinks =  8.111375491900796
# 1Mw_btw_Xlinks =  12.772199218500258
# 1Total MW =  531798
# 8.819166666666666 7.6923076923076925 1.1464916666666665
# 1562
# 1Mn_btw_Xlinks =  8.113394073796991
# 1Mw_btw_Xlinks =  12.770223276032405
# 1Total MW =  607320
# 8.781666666666666 7.687379884689301 1.1423484722222221
# 1562
# 1Mn_btw_Xlinks =  8.115026485189672
# 1Mw_btw_Xlinks =  12.771545321096085
# 1Total MW =  683269
# 8.880333333333333 7.687379884689301 1.155183361111111
# 1562
# 1Mn_btw_Xlinks =  8.10932764140875
# 1Mw_btw_Xlinks =  12.769247371828955
# 1Total MW =  759844
# Mn_btw_Xlinks =  8.117497706373083
# Mw_btw_Xlinks =  12.791696345729763
# Total Segments =  93738
# Total MW =  760918
# pdi= (7.687379884689301, 1.155183361111111)
# monomer =  5000
# crosslinker =  3750
# TTC =  0
# TFK =  1250
# initiator =  62
# r1 =  1
# r2 =  1
# 5.7011666666666665 4.729996058336618 1.2053216527777777
# 2562
# 1Mn_btw_Xlinks =  8.123260227752004
# 1Mw_btw_Xlinks =  12.485468776365831
# 1Total MW =  77041
# 5.729333333333333 4.7281323877068555 1.211754
# 2562
# 1Mn_btw_Xlinks =  8.1072443929662
# 1Mw_btw_Xlinks =  12.475676834059575
# 1Total MW =  153989
# 5.7845 4.7412090082971154 1.2200474583333336
# 2562
# 1Mn_btw_Xlinks =  8.096788894342003
# 1Mw_btw_Xlinks =  12.460118024496794
# 1Total MW =  230969
# 5.8005 4.746835443037975 1.221972
# 2562
# 1Mn_btw_Xlinks =  8.100762714100973
# 1Mw_btw_Xlinks =  12.458738670645651
# 1Total MW =  306946
# 5.796 4.729996058336618 1.225371
# 2562
# 1Mn_btw_Xlinks =  8.106861998985286
# 1Mw_btw_Xlinks =  12.461494131482945
# 1Total MW =  383487
# 5.693666666666667 4.7225501770956315 1.2056339166666667
# 2562
# 1Mn_btw_Xlinks =  8.114477046435809
# 1Mw_btw_Xlinks =  12.481366297757006
# 1Total MW =  460456
# 5.7095 4.733727810650888 1.206131875
# 2562
# 1Mn_btw_Xlinks =  8.1206364104272
# 1Mw_btw_Xlinks =  12.478749443080497
# 1Total MW =  536433
# 5.7285 4.73186119873817 1.210623
# 2562
# 1Mn_btw_Xlinks =  8.1200365190468
# 1Mw_btw_Xlinks =  12.483095644692417
# 1Total MW =  613688
# 5.7365 4.726270185112249 1.2137477916666668
# 2562
# 1Mn_btw_Xlinks =  8.116769002752488
# 1Mw_btw_Xlinks =  12.471354517643206
# 1Total MW =  690039
# 5.719833333333334 4.729996058336618 1.2092680972222223
# 2562
# 1Mn_btw_Xlinks =  8.117876196121601
# 1Mw_btw_Xlinks =  12.476440582491863
# 1Total MW =  766912
# Mn_btw_Xlinks =  8.123980147938074
# Mw_btw_Xlinks =  12.49420873561302
# Total Segments =  94499
# Total MW =  767708
# pdi= (4.729996058336618, 1.2092680972222223)
# monomer =  5000
# crosslinker =  5000
# TTC =  250
# TFK =  0
# initiator =  62
# r1 =  1
# r2 =  1
# 22.640666666666668 21.352313167259787 1.060337888888889
# 562
# 1Mn_btw_Xlinks =  8.47358708189158
# 1Mw_btw_Xlinks =  13.77230283396401
# 1Total MW =  73466
# 22.579666666666668 21.352313167259787 1.0574810555555556
# 562
# 1Mn_btw_Xlinks =  8.468670813176688
# 1Mw_btw_Xlinks =  13.78385583134988
# 1Total MW =  147050
# 22.579166666666666 21.352313167259787 1.0574576388888888
# 562
# 1Mn_btw_Xlinks =  8.482267318726173
# 1Mw_btw_Xlinks =  13.792986979970582
# 1Total MW =  220276
# 22.629333333333335 21.352313167259787 1.0598071111111111
# 562
# 1Mn_btw_Xlinks =  8.483129499522942
# 1Mw_btw_Xlinks =  13.777836854052065
# 1Total MW =  293406
# 22.714 21.352313167259787 1.0637723333333333
# 562
# 1Mn_btw_Xlinks =  8.481012073781656
# 1Mw_btw_Xlinks =  13.76318282286075
# 1Total MW =  367372
# 22.7495 21.352313167259787 1.0654349166666668
# 562
# 1Mn_btw_Xlinks =  8.47515742589464
# 1Mw_btw_Xlinks =  13.764704816356858
# 1Total MW =  441454
# 22.607166666666668 21.352313167259787 1.0587689722222222
# 562
# 1Mn_btw_Xlinks =  8.471025211188904
# 1Mw_btw_Xlinks =  13.76997757203722
# 1Total MW =  515428
# 22.669666666666668 21.352313167259787 1.0616960555555557
# 562
# 1Mn_btw_Xlinks =  8.472054695933789
# 1Mw_btw_Xlinks =  13.765407851905211
# 1Total MW =  588596
# 22.564333333333334 21.352313167259787 1.0567629444444444
# 562
# 1Mn_btw_Xlinks =  8.475308326083619
# 1Mw_btw_Xlinks =  13.776700318809777
# 1Total MW =  662464
# 22.53 21.352313167259787 1.055155
# 562
# 1Mn_btw_Xlinks =  8.476576721893219
# 1Mw_btw_Xlinks =  13.779632358138194
# 1Total MW =  735716
# Mn_btw_Xlinks =  8.477303101525417
# Mw_btw_Xlinks =  13.782494060853823
# Total Segments =  86796
# Total MW =  735796
# pdi= (21.352313167259787, 1.055155)
# monomer =  5000
# crosslinker =  5000
# TTC =  750
# TFK =  0
# initiator =  62
# r1 =  1
# r2 =  1
# 8.813 7.687379884689301 1.1464244166666668
# 1562
# 1Mn_btw_Xlinks =  9.603078169299312
# 1Mw_btw_Xlinks =  15.309489666807254
# 1Total MW =  71130
# 8.81 7.682458386683739 1.1467683333333334
# 1562
# 1Mn_btw_Xlinks =  9.636475242122494
# 1Mw_btw_Xlinks =  15.33818387713214
# 1Total MW =  141290
# 8.834 7.687379884689301 1.1491561666666668
# 1562
# 1Mn_btw_Xlinks =  9.622018016386765
# 1Mw_btw_Xlinks =  15.29649981181784
# 1Total MW =  212560
# 8.7235 7.682458386683739 1.1355089166666665
# 1562
# 1Mn_btw_Xlinks =  9.632788002726652
# 1Mw_btw_Xlinks =  15.281665522634153
# 1Total MW =  282626
# 8.8125 7.6923076923076925 1.145625
# 1562
# 1Mn_btw_Xlinks =  9.619903848765516
# 1Mw_btw_Xlinks =  15.278211962414167
# 1Total MW =  354176
# 8.847 7.687379884689301 1.15084725
# 1562
# 1Mn_btw_Xlinks =  9.622759369907659
# 1Mw_btw_Xlinks =  15.279143499571937
# 1Total MW =  425172
# 8.804166666666667 7.702182284980744 1.1430743055555557
# 1562
# 1Mn_btw_Xlinks =  9.622611526685013
# 1Mw_btw_Xlinks =  15.281959778147442
# 1Total MW =  496546
# 8.804833333333333 7.682458386683739 1.1460958055555555
# 1562
# 1Mn_btw_Xlinks =  9.616640390581296
# 1Mw_btw_Xlinks =  15.270281132993464
# 1Total MW =  567276
# 8.865833333333333 7.682458386683739 1.1540359722222222
# 1562
# 1Mn_btw_Xlinks =  9.617519305019306
# 1Mw_btw_Xlinks =  15.265060845565174
# 1Total MW =  637680
# 8.784666666666666 7.6923076923076925 1.1420066666666666
# 1562
# 1Mn_btw_Xlinks =  9.616253189294827
# 1Mw_btw_Xlinks =  15.266087467046026
# 1Total MW =  708564
# Mn_btw_Xlinks =  9.622257499898238
# Mw_btw_Xlinks =  15.283585036028033
# Total Segments =  73701
# Total MW =  709170
# pdi= (7.6923076923076925, 1.1420066666666666)
# monomer =  5000
# crosslinker =  5000
# TTC =  1250
# TFK =  0
# initiator =  62
# r1 =  1
# r2 =  1
# 5.7251666666666665 4.746835443037975 1.2061017777777776
# 2562
# 1Mn_btw_Xlinks =  10.323861900397189
# 1Mw_btw_Xlinks =  15.839005622965374
# 1Total MW =  67580
# 5.735333333333333 4.726270185112249 1.2135009444444445
# 2562
# 1Mn_btw_Xlinks =  10.294744859101295
# 1Mw_btw_Xlinks =  15.805193460087297
# 1Total MW =  135170
# 5.752166666666667 4.73559589581689 1.2146658611111112
# 2562
# 1Mn_btw_Xlinks =  10.285076821662187
# 1Mw_btw_Xlinks =  15.7803502405932
# 1Total MW =  202832
# 5.724333333333333 4.720692368214005 1.212604611111111
# 2562
# 1Mn_btw_Xlinks =  10.295220672307341
# 1Mw_btw_Xlinks =  15.796731895485811
# 1Total MW =  270126
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-30a79b228915> in <module>
#     943         initiation()
#     944
# --> 945         simulation()
#     946
#     947         pdi = MW_Calculator()
#
# <ipython-input-1-30a79b228915> in simulation()
#     483
#     484         if chain.tail == 'radical':
# --> 485             grow_outcome = chain_grow(chain)
#     486
#     487             if grow_outcome == 1:
#
# <ipython-input-1-30a79b228915> in chain_grow(chain)
#     421             weights.append(k_transfer_to_TFK)
#     422         elif molecule.kind == 1:
# --> 423             if len(chain.component) == 0:
#     424                 weights.append(1)
#     425             elif chain.component[-1].kind == 1:
#
# KeyboardInterrupt:

# %%
# %matplotlib inline
import numpy as np

import statistics
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from brokenaxes import brokenaxes

#fig, ax = plt.subplots(3,2, dpi=600, figsize=(8,8))


fig = plt.figure(dpi=600, figsize=(8,8))

spec2 = gridspec.GridSpec(ncols=2, nrows=3, figure=fig)
ax[0,0] = fig.add_subplot(spec2[0, 0])
ax[0,1] = fig.add_subplot(spec2[0, 1])
ax[1,0] = fig.add_subplot(spec2[1, 0])
ax[1,1] = fig.add_subplot(spec2[1, 1])
#ax[2,0] = brokenaxes(xlims=((0, 40), (160, 230)), hspace=.1, subplot_spec=spec2[2,0])
ax[2,0] = fig.add_subplot(spec2[2, 0])
ax[2,1] = fig.add_subplot(spec2[2, 1])


fig.tight_layout(pad=4.0)

#Fig1a

width = 0.25

bar1 = ax[0,0].bar(np.asarray(all_data[0][0]) - 1.5*width, list(map(lambda x: x/repeats,  all_data[0][1])), width = width, facecolor='dodgerblue') 
bar2 = ax[0,0].bar(np.asarray(all_data[1][0]) - 0.5*width, list(map(lambda x: x/repeats,  all_data[1][1])), width = width, facecolor='green') 
bar3 = ax[0,0].bar(np.asarray(all_data[2][0]) + 0.5*width, list(map(lambda x: x/repeats,  all_data[2][1])), width = width, facecolor='orange')
ax[0,0].bar(np.asarray(all_data[3][0]) + 1.5*width, list(map(lambda x: x/repeats,  all_data[3][1])), width = width, facecolor='red') 
ax[0,0].set_xlim([0,30])
ax[0,0].set_ylim([0,4200])

ax[0,0].set_xlabel("Elastic segment length", fontsize = 12)
ax[0,0].set_ylabel("Occurrence", fontsize = 12)
#ax[0,0].set_title("Length distribution of elastic segments",fontweight="bold",fontsize = 10)


ax[0,0].legend(['Control-S', 'TFK-5S', 'TFK-15S', 'TFK-25S'])



#Fig1b

width = 0.25

bar1 = ax[0,1].bar(np.asarray(all_data[0][0]) - 1.5*width, list(map(lambda x: x/repeats,  all_data[0][1])), width = width, facecolor='dodgerblue') 
bar2 = ax[0,1].bar(np.asarray(all_data[4][0]) - 0.5*width, list(map(lambda x: x/repeats,  all_data[4][1])), width = width, facecolor='green') 
bar3 = ax[0,1].bar(np.asarray(all_data[5][0]) + 0.5*width, list(map(lambda x: x/repeats,  all_data[5][1])), width = width, facecolor='orange')
ax[0,1].bar(np.asarray(all_data[6][0]) + 1.5*width, list(map(lambda x: x/repeats,  all_data[6][1])), width = width, facecolor='red') 
ax[0,1].set_xlim([0,30])
ax[0,1].set_ylim([0,4200])

ax[0,1].set_xlabel("Elastic segment length", fontsize = 12)
ax[0,1].set_ylabel("Occurrence", fontsize = 12)
#ax[0,0].set_title("Length distribution of elastic segments",fontweight="bold",fontsize = 10)


ax[0,1].legend(['Control-S', 'TTC-5S', 'TTC-15S', 'TTC-25S'])


#Fig1c

x_number = [0,5,15,25]

def extract_data(expermnts, order):
    avg = []
    std = []
    for i in expermnts:
        repeats = []
        for j in range(len(all_mw_data[i])):
            repeats.append(all_mw_data[i][j][order])
        #print (repeats)             
        avg.append(statistics.mean(repeats))
        std.append(statistics.stdev(repeats))
    return avg, std

avg_mn_tfk, std_mn_tfk = extract_data([0,1,2,3], 'mn')
avg_mn_ttc, std_mn_ttc = extract_data([0,4,5,6], 'mn')
              
line1 = ax[1,0].errorbar(x_number, avg_mn_tfk,yerr = std_mn_tfk, fmt = 'o-', color = 'darkorange', ecolor='black', capsize=6, capthick=1)
line2 = ax[1,0].errorbar(x_number, avg_mn_ttc,yerr = std_mn_ttc, fmt = 's', linestyle='dashed', color = 'darkgoldenrod', ecolor='black', capsize=6, capthick=1)

#ax[1,0].set_title("Percentage of dangling chains",fontweight="bold",fontsize = 10)
ax[1,0].set_xlabel("TFK or TTC%", fontsize = 12)
ax[1,0].set_xticks([0,5,15,25])
ax[1,0].set_ylabel("Average length \n of elastic segments", fontsize = 12)
ax[1,0].legend(['TFK', 'TTC'], loc='center right')


#Fig1d

def extract_data_percentage(expermnts, order):
    total = 90000
    avg = []
    std = []
    for i in expermnts:
        repeats = []
        for j in range(len(all_mw_data[i])):
            repeats.append(all_mw_data[i][j][order])
        percentages = []
        for j in range(len(repeats)):
            if j == 0: percentages.append((1-(repeats[0]/total))*100)
            else:
                percentages.append((1-((repeats[j]-repeats[j-1])/total))*100)
        repeats = percentages
        avg.append(statistics.mean(repeats))
        std.append(statistics.stdev(repeats))
    return avg, std

avg_w_tfk, std_w_tfk = extract_data_percentage([0,1,2,3], 'total_mw')
avg_w_ttc, std_w_ttc = extract_data_percentage([0,4,5,6], 'total_mw')
              
line3 = ax[1,1].errorbar(x_number, avg_w_tfk,yerr = std_w_tfk, fmt = 'o-', color = 'darkorange', ecolor='black', capsize=6, capthick=1)
line4 = ax[1,1].errorbar(x_number, avg_w_ttc,yerr = std_w_ttc, fmt = 's', linestyle='dashed', color = 'darkgoldenrod', ecolor='black', capsize=6, capthick=1)

#ax[1,0].set_title("Percentage of dangling chains",fontweight="bold",fontsize = 10)
ax[1,1].set_xlabel("TFK or TTC%", fontsize = 12)
ax[1,1].set_xticks([0,5,15,25])
ax[1,1].set_ylabel("% of Molecular Weight \n in Dangling Chains", fontsize = 12)
ax[1,1].legend(['TFK', 'TTC'], loc='center right')


#fig1e
all_chain_lengths = []
all_chain_neighbors = []

avg_chain_neighbors = []
std_chain_neighbors = []

for experiment in range(len(all_chain_list)):
    all_kcl_in_exprmt = []
    all_nbr_in_exprmt = []
    for repeat in range(len(all_chain_list[experiment])):
        kinetic_chain_length = []
        neighbor = []
        #print(len(all_chain_list[experiment][repeat]))
        for chain0 in all_chain_list[experiment][repeat]:
            kinetic_chain_length.append(len(chain0.component))
            neighbor.append(len(chain0.neighbors))
            
            all_kcl_in_exprmt.append(len(chain0.component))
            all_nbr_in_exprmt.append(len(chain0.neighbors))

    all_chain_lengths.append(all_kcl_in_exprmt)
    all_chain_neighbors.append(all_nbr_in_exprmt)
    
    avg_chain_neighbors.append(statistics.mean(all_nbr_in_exprmt))
    std_chain_neighbors.append(statistics.stdev(all_nbr_in_exprmt))
    
print(avg_chain_neighbors)
#print(std_chain_neighbors)
            
bin_width = 2

sublist = all_chain_lengths[0]
a_heights, a_bins = np.histogram(sublist,bins=range(min(sublist), max(sublist) + bin_width, bin_width))

sublist = all_chain_lengths[1]
b_heights, b_bins = np.histogram(sublist,bins=range(1, max(sublist) + bin_width, bin_width))

sublist = all_chain_lengths[2]
c_heights, c_bins = np.histogram(sublist,bins=range(1, max(sublist) + bin_width, bin_width))

sublist = all_chain_lengths[3]
d_heights, d_bins = np.histogram(sublist,bins=range(1, max(sublist) + bin_width, bin_width))


width = (a_bins[1] - a_bins[0])/5



#ax[2,0].bar(a_bins[:-1], a_heights, width=width, facecolor='dodgerblue')
ax[2,0].bar(b_bins[:-1] + width, b_heights/repeats, width=width, facecolor='green')
ax[2,0].bar(c_bins[:-1] + 2*width, c_heights/repeats, width=width, facecolor='orange')
ax[2,0].bar(d_bins[:-1] + 3*width, d_heights/repeats, width=width, facecolor='red')
#ax[2,0].set_xlim([0,40])

ax[2,0].set_xlabel("Kinetic chain length", fontsize = 12)
ax[2,0].set_ylabel("Occurrence", fontsize = 12)
#ax[1,1].set_title("Length distribution of vinyl chains",fontweight="bold",fontsize = 10)

ax[2,0].legend(['TFK-5S', 'TFK-15S', 'TFK-25S'])


#fig1f

x_number = [0,5,15,25]


avg_nbr_tfk = avg_chain_neighbors[0:4]
std_nbr_tfk = std_chain_neighbors[0:4]

avg_nbr_ttc = avg_chain_neighbors[0:1] + avg_chain_neighbors[4:7]
std_nbr_ttc = std_chain_neighbors[0:1] + avg_chain_neighbors[4:7]

print(avg_nbr_ttc)
print(std_nbr_ttc)

#line5 = ax[2,1].errorbar(x_number, avg_nbr_tfk,yerr = std_nbr_tfk, fmt = 'o-', color = 'darkorange', ecolor='black', capsize=6, capthick=1)
#line6 = ax[2,1].errorbar(x_number, avg_nbr_ttc,yerr = std_nbr_ttc, fmt = 's', linestyle='dashed', color = 'darkgoldenrod', ecolor='black', capsize=6, capthick=1)
line5 = ax[2,1].plot(x_number, avg_nbr_tfk, 'o-', color = 'darkorange')
line6 = ax[2,1].plot(x_number, avg_nbr_ttc, 's', linestyle='dashed', color = 'darkgoldenrod')


#ax[1,0].set_title("Percentage of dangling chains",fontweight="bold",fontsize = 10)
ax[2,1].set_xlabel("TFK or TTC%", fontsize = 12)
ax[2,1].set_xticks([0,5,15,25])
ax[2,1].set_ylabel("Average crosslinks\n per chain", fontsize = 12)
ax[2,1].legend(['TFK', 'TTC'], loc='center right')
ax[2,1].set_ylim([0,65])
ax[2,1].set_xlim([-2,25])


texts = ['A', 'B', 'C', 'D', 'E', 'F']
axes = fig.get_axes()
for a,l in zip(axes, texts):
    a.annotate(l, xy=(0.02, 0.85), xycoords="axes fraction", fontsize=15, ) #weight = 'bold'
#plt.suptitle('Label_Distance Consistent', fontsize = 20)
# Out:
# [49.75483870967742, 12.990035587188611, 5.968629961587708, 4.39352068696331, 12.116014234875445, 5.037131882202305, 3.4718188914910226]
# [49.75483870967742, 12.116014234875445, 5.037131882202305, 3.4718188914910226]
# [3.0812202762452245, 12.116014234875445, 5.037131882202305, 3.4718188914910226]

# %%
print(all_mw_data)
print(all_chain_list)
# Out:
# [[{'mn': 7.976420150053591, 'mw': 12.847621607094867, 'total_mw': 7442}, {'mn': 7.9283833596629805, 'mw': 12.810308182784272, 'total_mw': 15056}, {'mn': 7.936507936507937, 'mw': 12.79111111111111, 'total_mw': 22500}, {'mn': 7.951621477937268, 'mw': 12.780236678478305, 'total_mw': 29914}, {'mn': 7.93989417989418, 'mw': 12.784518605395032, 'total_mw': 37516}, {'mn': 7.939009342499559, 'mw': 12.788578533682667, 'total_mw': 45038}, {'mn': 7.916067146282973, 'mw': 12.792184186610118, 'total_mw': 52816}, {'mn': 7.910662824207493, 'mw': 12.802053320086108, 'total_mw': 60390}, {'mn': 7.903796878639646, 'mw': 12.794612596151012, 'total_mw': 67862}, {'mn': 7.90598111227702, 'mw': 12.794648545338713, 'total_mw': 75344}], [{'mn': 8.006451612903225, 'mw': 12.837228041901692, 'total_mw': 7446}, {'mn': 8.035326086956522, 'mw': 12.775177544808928, 'total_mw': 14785}, {'mn': 8.02054054054054, 'mw': 12.803836995102664, 'total_mw': 22257}, {'mn': 8.00268889486421, 'mw': 12.780659901888313, 'total_mw': 29762}, {'mn': 7.969722997637964, 'mw': 12.752714535901926, 'total_mw': 37115}, {'mn': 7.992808342322905, 'mw': 12.797102753284147, 'total_mw': 44456}, {'mn': 7.97475906379073, 'mw': 12.783660394007404, 'total_mw': 52131}, {'mn': 8.004691060179601, 'mw': 12.811764311906636, 'total_mw': 59723}, {'mn': 7.995120790193979, 'mw': 12.807451289760802, 'total_mw': 67183}, {'mn': 7.984400042739609, 'mw': 12.814013863983085, 'total_mw': 74726}], [{'mn': 8.076761303890642, 'mw': 12.772425465434189, 'total_mw': 7681}, {'mn': 8.054939249867935, 'mw': 12.685073452256034, 'total_mw': 15248}, {'mn': 8.041798384264137, 'mw': 12.702205721773312, 'total_mw': 22895}, {'mn': 8.015906680805939, 'mw': 12.610001322926314, 'total_mw': 30236}, {'mn': 8.02045164039199, 'mw': 12.629515512112198, 'total_mw': 37648}, {'mn': 8.03513753327418, 'mw': 12.629179734087195, 'total_mw': 45278}, {'mn': 8.008802549704052, 'mw': 12.62436990714421, 'total_mw': 52770}, {'mn': 8.0321722946025, 'mw': 12.639180376708929, 'total_mw': 60418}, {'mn': 8.070233325477256, 'mw': 12.713188481981193, 'total_mw': 68484}, {'mn': 8.035327816677276, 'mw': 12.656540050963152, 'total_mw': 75741}], [{'mn': 8.089598352214212, 'mw': 12.459452577975812, 'total_mw': 7855}, {'mn': 8.06642259414226, 'mw': 12.381443298969073, 'total_mw': 15423}, {'mn': 8.01213171577123, 'mw': 12.345360155743023, 'total_mw': 23115}, {'mn': 8.028556593977155, 'mw': 12.335769255642502, 'total_mw': 30926}, {'mn': 8.056958063843105, 'mw': 12.379288914208768, 'total_mw': 38617}, {'mn': 8.038790843962957, 'mw': 12.367430335173673, 'total_mw': 46006}, {'mn': 8.04982740507279, 'mw': 12.356588858229546, 'total_mw': 53636}, {'mn': 8.06130520764667, 'mw': 12.36583530951018, 'total_mw': 61145}, {'mn': 8.078222117978187, 'mw': 12.39671617089848, 'total_mw': 68883}, {'mn': 8.048785638859556, 'mw': 12.354595785993546, 'total_mw': 76222}], [{'mn': 8.465063001145475, 'mw': 13.818132611637347, 'total_mw': 7390}, {'mn': 8.488425925925926, 'mw': 13.86910280883556, 'total_mw': 14668}, {'mn': 8.350056582421727, 'mw': 13.744127213588724, 'total_mw': 22136}, {'mn': 8.332022471910113, 'mw': 13.683365922729418, 'total_mw': 29662}, {'mn': 8.367920253738106, 'mw': 13.657786441412172, 'total_mw': 36936}, {'mn': 8.413714718696722, 'mw': 13.734690201729107, 'total_mw': 44416}, {'mn': 8.408310158678226, 'mw': 13.658210116731517, 'total_mw': 51400}, {'mn': 8.453721030660716, 'mw': 13.737501702765291, 'total_mw': 58728}, {'mn': 8.442477876106194, 'mw': 13.721568984899584, 'total_mw': 65826}, {'mn': 8.442296628696353, 'mw': 13.722946082974431, 'total_mw': 73372}], [{'mn': 9.39787798408488, 'mw': 14.942703923228901, 'total_mw': 7086}, {'mn': 9.464166108506364, 'mw': 14.98343949044586, 'total_mw': 14130}, {'mn': 9.471111111111112, 'mw': 15.062036602534022, 'total_mw': 21310}, {'mn': 9.439973395410709, 'mw': 15.02557598816318, 'total_mw': 28386}, {'mn': 9.41814334832055, 'mw': 15.035888795282224, 'total_mw': 35610}, {'mn': 9.371718508713876, 'mw': 14.93027635233746, 'tot ...
# []

# %%
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:65: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "xr" (-> color='r'). The keyword argument will take precedence.
# 193.5483870967742 194.56343333333334 1.0052444055555556
# 21.35611318739989 25.1136 1.1759443200000002
# 7.734949078251901 9.812633333333334 1.2686099461111113
# 4.815022871358639 6.349583333333333 1.3187026319444444
